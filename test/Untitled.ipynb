# %%
import pandas as pd

df = pd.read_csv('../output/codewar_users.csv', index_col=0)

# %%
df.head()
# Out:
#    1 kyu  2 kyu  3 kyu  4 kyu  5 kyu  6 kyu  7 kyu  8 kyu  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    advanced language features  agda  ...  total languages trained  \
# 0                         NaN   NaN  ...                     10.0
# 1                         NaN   NaN  ...                      7.0
# 2                         NaN   NaN  ...                      3.0
# 3                         NaN   NaN  ...                      9.0
# 4                         NaN   NaN  ...                      9.0
#
#    total stars        translations  trees  typescript              user  \
# 0        125.0  285 (239 approved)    NaN         NaN         FArekkusu
# ...
